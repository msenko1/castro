# %% [markdown]
# # Bigram Probability Analysis

# %%
import pandas as pd
import sys
import os 

sys.path.append(os.path.abspath(".."))

from scripts import prob

# %%
df = pd.read_csv("/Users/senko/Desktop/castro/data/processed/micro_bigram.csv")

# %% [markdown]
# ## Castro Residents

# %%
# Castro_res participants with response_site1=castro and response_site2=marina
prob.micro_prob(df, target_fieldsite="castro_res", target_r1_site="castro", target_r2_site="marina")

# Castro_res participants with response_site1=castro and response_site2=mission
prob.micro_prob(df, target_fieldsite="castro_res", target_r1_site="castro", target_r2_site="mission")
# Out:
# Probability of response2 given response1 for castro_res participants with response_site1=castro and response_site2=marina:
#        category1     category2  probability
# 0       antitask        boring     1.000000
# 1            bad           bad     1.000000
# 2         boring        boring     1.000000
# 3         change         other     1.000000
# 4      community      antitask     0.200000
# 5      community           bad     0.100000
# 6      community       chaotic     0.100000
# 7      community     geography     0.200000
# 8      community     normative     0.100000
# 9      community         other     0.100000
# 10     community         young     0.200000
# 11       diverse      antitask     0.250000
# 12       diverse    gentrified     0.375000
# 13       diverse     normative     0.250000
# 14       diverse         other     0.125000
# 15           fun      antitask     0.360000
# 16           fun           bad     0.040000
# 17           fun        boring     0.040000
# ...

# %% [markdown]
# ## Castro Visitors

# %%
# Castro_vis participants with response_site1=castro and response_site2=marina
prob.micro_prob(df, target_fieldsite="castro_vis", target_r1_site="castro", target_r2_site="marina")

# Castro_vis participants with response_site1=castro and response_site2=mission
prob.micro_prob(df, target_fieldsite="castro_vis", target_r1_site="castro", target_r2_site="mission")
# Out:
# Probability of response2 given response1 for castro_vis participants with response_site1=castro and response_site2=marina:
#     category1   category2  probability
# 0      boring    antitask     0.666667
# 1      boring       other     0.333333
# 2      change       other     1.000000
# 3     chaotic         bad     0.285714
# 4     chaotic      boring     0.142857
# 5     chaotic     chaotic     0.142857
# 6     chaotic  gentrified     0.142857
# 7     chaotic   normative     0.285714
# 8   community  gentrified     0.333333
# 9   community      gritty     0.333333
# 10  community   normative     0.333333
# 11        fun    antitask     0.045455
# 12        fun         bad     0.181818
# 13        fun      boring     0.136364
# 14        fun   community     0.045455
# 15        fun  gentrified     0.136364
# 16        fun      latino     0.045455
# 17        fun        nice     0.045455
# 18        fun   normative     0.227273
# 19        fun       other     0.090909
# ...

# %% [markdown]
# ## Marina Residents

# %%
# Marina participants with response_site1=marina and response_site2=castro
prob.micro_prob(df, target_fieldsite="marina_res", target_r1_site="marina", target_r2_site="castro")

# Marina participants with response_site1=marina and response_site2=mission
prob.micro_prob(df, target_fieldsite="marina_res", target_r1_site="castro", target_r2_site="marina")
# Out:
# Probability of response2 given response1 for marina_res participants with response_site1=marina and response_site2=castro:
#        category1  category2  probability
# 0        actions   antitask     1.000000
# 1            bad     boring     0.500000
# 2            bad        gay     0.500000
# 3         boring        fun     0.500000
# 4         boring      other     0.500000
# 5        chaotic    diverse     0.500000
# 6        chaotic        fun     0.500000
# 7      community   antitask     1.000000
# 8        diverse       nice     1.000000
# 9            fun   antitask     0.250000
# 10           fun    diverse     0.166667
# 11           fun        fun     0.500000
# 12           fun      other     0.083333
# 13    gentrified   antitask     0.133333
# 14    gentrified    diverse     0.066667
# 15    gentrified        fun     0.266667
# 16    gentrified        gay     0.533333
# 17     geography   antitask     0.285714
# 18     geography  community     0.142857
# ...

# %% [markdown]
# ## Mission Residents

# %%
# Mission participants with response_site1=mission and response_site2=castro
prob.micro_prob(df, target_fieldsite="mission_res", target_r1_site="mission", target_r2_site="castro")

# Mission participants with response_site1=castro and response_site2=mission
prob.micro_prob(df, target_fieldsite="mission_res", target_r1_site="castro", target_r2_site="mission")
# Out:
# Probability of response2 given response1 for mission_res participants with response_site1=mission and response_site2=castro:
#      category1   category2  probability
# 0          bad         gay     1.000000
# 1      chaotic         fun     1.000000
# 2    community   community     0.333333
# 3    community         fun     0.166667
# 4    community   geography     0.166667
# 5    community        nice     0.166667
# 6    community     special     0.166667
# 7      diverse     diverse     0.166667
# 8      diverse         fun     0.500000
# 9      diverse         gay     0.250000
# 10     diverse  gentrified     0.083333
# 11         fun      boring     0.055556
# 12         fun   community     0.055556
# 13         fun     diverse     0.111111
# 14         fun         fun     0.500000
# 15         fun         gay     0.111111
# 16         fun        nice     0.111111
# 17         fun     special     0.055556
# 18  gentrified         gay     0.666667
# ...
