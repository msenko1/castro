# %% [markdown]
# # Bigram Probability Analysis

# %%
import pandas as pd
import sys
import os 

sys.path.append(os.path.abspath(".."))

from scripts import prob

# %%
df = pd.read_csv("/Users/senko/Desktop/castro/data/processed/micro_bigram.csv")

df_clean = pd.read_csv("/Users/senko/Desktop/castro/data/processed/clean_bigram.csv")

df_all = pd.read_csv("/Users/senko/Desktop/castro/data/processed/all_bigram.csv")

# %% [markdown]
# # Micro Level
# ## Castro Residents

# %%
# Castro_res participants with response_site1=castro and response_site2=marina
prob.forward_prob(df, target_fieldsite="castro_res", target_r1_site="castro", target_r2_site="marina", count_filter=0)
prob.backward_prob(df, target_fieldsite="castro_res", target_r1_site="castro", target_r2_site="marina", count_filter=0)

# Castro_res participants with response_site1=castro and response_site2=mission
prob.forward_prob(df, target_fieldsite="castro_res", target_r1_site="castro", target_r2_site="mission", count_filter=0)
prob.backward_prob(df, target_fieldsite="castro_res", target_r1_site="castro", target_r2_site="mission", count_filter=0)
# Out:
# Forward probability of response2 given response1 for castro_res participants with response_site1=castro and response_site2=marina:
#        category1     category2  count  probability
# 0       antitask        boring      1     1.000000
# 1            bad           bad      1     1.000000
# 2         boring        boring      1     1.000000
# 3         change         other      1     1.000000
# 4      community      antitask      2     0.200000
# 5      community           bad      1     0.100000
# 6      community       chaotic      1     0.100000
# 7      community     geography      2     0.200000
# 8      community     normative      1     0.100000
# 9      community         other      1     0.100000
# 10     community         young      2     0.200000
# 11       diverse      antitask      2     0.250000
# 12       diverse    gentrified      3     0.375000
# 13       diverse     normative      2     0.250000
# 14       diverse         other      1     0.125000
# 15           fun      antitask      9     0.360000
# 16           fun           bad      1     0.040000
# 17           fun        boring      1     0.040000
# 18           fun    gentrified      6     0.240000
# 19           fun  institutions      1     0.040000
# 20           fun          nice      1     0.040000
# 21           fun     normative      2     0.080000
# 22           fun         other      2     0.080000
# 23           fun        sexual      1     0.040000
# 24           fun       special      1     0.040000
# 25           gay        boring      1     0.076923
# 26           gay    gentrified      4     0.307692
# 27           gay        gritty      1     0.076923
# 28           gay     normative      4     0.307692
# 29           gay         other      1     0.076923
# 30           gay         young      2     0.153846
# 31  institutions      antitask      1     1.000000
# 32          nice      antitask      2     0.222222
# 33          nice           bad      1     0.111111
# 34          nice        boring      1     0.111111
# 35          nice           fun      1     0.111111
# 36          nice    gentrified      1     0.111111
# 37          nice          nice      1     0.111111
# 38          nice     normative      1     0.111111
# 39          nice         other      1     0.111111
# 40     normative        boring      1     1.000000
# 41          open          nice      1     1.000000
# 42         other        boring      2     0.500000
# 43         other    gentrified      1     0.250000
# 44         other     normative      1     0.250000
# 45       special      antitask      1     0.250000
# 46       special    gentrified      2     0.500000
# 47       special          nice      1     0.250000
# Backward probability of response1 given response2 for castro_res participants with response_site1=castro and response_site2=marina:
#        category1     category2  count  probability
# 4      community      antitask      2     0.117647
# 11       diverse      antitask      2     0.117647
# 15           fun      antitask      9     0.529412
# 31  institutions      antitask      1     0.058824
# 32          nice      antitask      2     0.117647
# 45       special      antitask      1     0.058824
# 1            bad           bad      1     0.250000
# 5      community           bad      1     0.250000
# 16           fun           bad      1     0.250000
# 33          nice           bad      1     0.250000
# 0       antitask        boring      1     0.125000
# 2         boring        boring      1     0.125000
# 17           fun        boring      1     0.125000
# 25           gay        boring      1     0.125000
# 34          nice        boring      1     0.125000
# 40     normative        boring      1     0.125000
# 42         other        boring      2     0.250000
# 6      community       chaotic      1     1.000000
# 35          nice           fun      1     1.000000
# 12       diverse    gentrified      3     0.176471
# 18           fun    gentrified      6     0.352941
# 26           gay    gentrified      4     0.235294
# 36          nice    gentrified      1     0.058824
# 43         other    gentrified      1     0.058824
# 46       special    gentrified      2     0.117647
# 7      community     geography      2     1.000000
# 27           gay        gritty      1     1.000000
# 19           fun  institutions      1     1.000000
# 20           fun          nice      1     0.250000
# 37          nice          nice      1     0.250000
# 41          open          nice      1     0.250000
# 47       special          nice      1     0.250000
# 8      community     normative      1     0.090909
# 13       diverse     normative      2     0.181818
# 21           fun     normative      2     0.181818
# 28           gay     normative      4     0.363636
# 38          nice     normative      1     0.090909
# 44         other     normative      1     0.090909
# 3         change         other      1     0.142857
# 9      community         other      1     0.142857
# 14       diverse         other      1     0.142857
# 22           fun         other      2     0.285714
# 29           gay         other      1     0.142857
# 39          nice         other      1     0.142857
# 23           fun        sexual      1     1.000000
# 24           fun       special      1     1.000000
# 10     community         young      2     0.500000
# 30           gay         young      2     0.500000
# Forward probability of response2 given response1 for castro_res participants with response_site1=castro and response_site2=mission:
#     category1   category2  count  probability
# 0    antitask     special      1     0.500000
# 1    antitask     weather      1     0.500000
# 2      boring         fun      1     1.000000
# 3     chaotic     chaotic      1     0.500000
# 4     chaotic  gentrified      1     0.500000
# 5   community   community      1     0.200000
# 6   community         fun      2     0.400000
# 7   community  gentrified      1     0.200000
# 8   community     special      1     0.200000
# 9     diverse     chaotic      1     0.142857
# 10    diverse         fun      1     0.142857
# 11    diverse   geography      2     0.285714
# 12    diverse      gritty      1     0.142857
# 13    diverse        nice      1     0.142857
# 14    diverse     special      1     0.142857
# 15        fun    antitask      2     0.111111
# 16        fun        food      3     0.166667
# 17        fun         fun      9     0.500000
# 18        fun  gentrified      1     0.055556
# 19        fun        nice      1     0.055556
# 20        fun     special      1     0.055556
# 21        fun     weather      1     0.055556
# 22        gay    antitask      4     0.153846
# 23        gay     diverse      2     0.076923
# 24        gay        food      2     0.076923
# 25        gay         fun      2     0.076923
# 26        gay  gentrified      4     0.153846
# 27        gay      latino      6     0.230769
# 28        gay   normative      1     0.038462
# 29        gay       other      2     0.076923
# 30        gay     special      2     0.076923
# 31        gay     weather      1     0.038462
# 32  geography    antitask      1     0.500000
# 33  geography     special      1     0.500000
# 34       nice     chaotic      1     0.166667
# 35       nice     diverse      1     0.166667
# 36       nice         fun      2     0.333333
# 37       nice  gentrified      1     0.166667
# 38       nice      gritty      1     0.166667
# 39       open     chaotic      1     1.000000
# 40      other        food      1     0.500000
# 41      other      gritty      1     0.500000
# 42     sexual     diverse      1     1.000000
# 43    special    antitask      1     0.200000
# 44    special     diverse      1     0.200000
# 45    special        food      1     0.200000
# 46    special     special      2     0.400000
# Backward probability of response1 given response2 for castro_res participants with response_site1=castro and response_site2=mission:
#     category1   category2  count  probability
# 15        fun    antitask      2     0.250000
# 22        gay    antitask      4     0.500000
# 32  geography    antitask      1     0.125000
# 43    special    antitask      1     0.125000
# 3     chaotic     chaotic      1     0.250000
# 9     diverse     chaotic      1     0.250000
# 34       nice     chaotic      1     0.250000
# 39       open     chaotic      1     0.250000
# 5   community   community      1     1.000000
# 23        gay     diverse      2     0.400000
# 35       nice     diverse      1     0.200000
# 42     sexual     diverse      1     0.200000
# 44    special     diverse      1     0.200000
# 16        fun        food      3     0.428571
# 24        gay        food      2     0.285714
# 40      other        food      1     0.142857
# 45    special        food      1     0.142857
# 2      boring         fun      1     0.058824
# 6   community         fun      2     0.117647
# 10    diverse         fun      1     0.058824
# 17        fun         fun      9     0.529412
# 25        gay         fun      2     0.117647
# 36       nice         fun      2     0.117647
# 4     chaotic  gentrified      1     0.125000
# 7   community  gentrified      1     0.125000
# 18        fun  gentrified      1     0.125000
# 26        gay  gentrified      4     0.500000
# 37       nice  gentrified      1     0.125000
# 11    diverse   geography      2     1.000000
# 12    diverse      gritty      1     0.333333
# 38       nice      gritty      1     0.333333
# 41      other      gritty      1     0.333333
# 27        gay      latino      6     1.000000
# 13    diverse        nice      1     0.500000
# 19        fun        nice      1     0.500000
# 28        gay   normative      1     1.000000
# 29        gay       other      2     1.000000
# 0    antitask     special      1     0.111111
# 8   community     special      1     0.111111
# 14    diverse     special      1     0.111111
# 20        fun     special      1     0.111111
# 30        gay     special      2     0.222222
# 33  geography     special      1     0.111111
# 46    special     special      2     0.222222
# 1    antitask     weather      1     0.333333
# 21        fun     weather      1     0.333333
# 31        gay     weather      1     0.333333

# %% [markdown]
# ## Castro Visitors

# %%
# Castro_vis participants with response_site1=castro and response_site2=marina
prob.forward_prob(df, target_fieldsite="castro_vis", target_r1_site="castro", target_r2_site="marina", count_filter=0)
prob.backward_prob(df, target_fieldsite="castro_vis", target_r1_site="castro", target_r2_site="marina", count_filter=0)

# Castro_vis participants with response_site1=castro and response_site2=mission
prob.forward_prob(df, target_fieldsite="castro_vis", target_r1_site="castro", target_r2_site="mission", count_filter=0)
prob.backward_prob(df, target_fieldsite="castro_vis", target_r1_site="castro", target_r2_site="mission", count_filter=0)
# Out:
# Forward probability of response2 given response1 for castro_vis participants with response_site1=castro and response_site2=marina:
#     category1   category2  count  probability
# 0      boring    antitask      2     0.666667
# 1      boring       other      1     0.333333
# 2      change       other      1     1.000000
# 3     chaotic         bad      2     0.285714
# 4     chaotic      boring      1     0.142857
# 5     chaotic     chaotic      1     0.142857
# 6     chaotic  gentrified      1     0.142857
# 7     chaotic   normative      2     0.285714
# 8   community  gentrified      1     0.333333
# 9   community      gritty      1     0.333333
# 10  community   normative      1     0.333333
# 11        fun    antitask      1     0.045455
# 12        fun         bad      4     0.181818
# 13        fun      boring      3     0.136364
# 14        fun   community      1     0.045455
# 15        fun  gentrified      3     0.136364
# 16        fun      latino      1     0.045455
# 17        fun        nice      1     0.045455
# 18        fun   normative      5     0.227273
# 19        fun       other      2     0.090909
# 20        fun       young      1     0.045455
# 21        gay    antitask      1     0.032258
# 22        gay         bad      1     0.032258
# 23        gay      boring      1     0.032258
# 24        gay         fun      1     0.032258
# 25        gay         gay      1     0.032258
# 26        gay  gentrified      7     0.225806
# 27        gay   geography      2     0.064516
# 28        gay        nice      2     0.064516
# 29        gay   normative     14     0.451613
# 30        gay     weather      1     0.032258
# 31  geography    antitask      1     0.500000
# 32  geography   geography      1     0.500000
# 33       nice      boring      1     0.166667
# 34       nice         fun      1     0.166667
# 35       nice  gentrified      1     0.166667
# 36       nice        nice      1     0.166667
# 37       nice   normative      1     0.166667
# 38       nice       other      1     0.166667
# 39       open         bad      1     1.000000
# 40      other        nice      1     0.500000
# 41      other       other      1     0.500000
# 42    special   normative      1     0.500000
# 43    special       other      1     0.500000
# Backward probability of response1 given response2 for castro_vis participants with response_site1=castro and response_site2=marina:
#     category1   category2  count  probability
# 0      boring    antitask      2     0.400000
# 11        fun    antitask      1     0.200000
# 21        gay    antitask      1     0.200000
# 31  geography    antitask      1     0.200000
# 3     chaotic         bad      2     0.250000
# 12        fun         bad      4     0.500000
# 22        gay         bad      1     0.125000
# 39       open         bad      1     0.125000
# 4     chaotic      boring      1     0.166667
# 13        fun      boring      3     0.500000
# 23        gay      boring      1     0.166667
# 33       nice      boring      1     0.166667
# 5     chaotic     chaotic      1     1.000000
# 14        fun   community      1     1.000000
# 24        gay         fun      1     0.500000
# 34       nice         fun      1     0.500000
# 25        gay         gay      1     1.000000
# 6     chaotic  gentrified      1     0.076923
# 8   community  gentrified      1     0.076923
# 15        fun  gentrified      3     0.230769
# 26        gay  gentrified      7     0.538462
# 35       nice  gentrified      1     0.076923
# 27        gay   geography      2     0.666667
# 32  geography   geography      1     0.333333
# 9   community      gritty      1     1.000000
# 16        fun      latino      1     1.000000
# 17        fun        nice      1     0.200000
# 28        gay        nice      2     0.400000
# 36       nice        nice      1     0.200000
# 40      other        nice      1     0.200000
# 7     chaotic   normative      2     0.083333
# 10  community   normative      1     0.041667
# 18        fun   normative      5     0.208333
# 29        gay   normative     14     0.583333
# 37       nice   normative      1     0.041667
# 42    special   normative      1     0.041667
# 1      boring       other      1     0.142857
# 2      change       other      1     0.142857
# 19        fun       other      2     0.285714
# 38       nice       other      1     0.142857
# 41      other       other      1     0.142857
# 43    special       other      1     0.142857
# 30        gay     weather      1     1.000000
# 20        fun       young      1     1.000000
# Forward probability of response2 given response1 for castro_vis participants with response_site1=castro and response_site2=mission:
#     category1     category2  count  probability
# 0      boring      antitask      1     1.000000
# 1      change       diverse      1     1.000000
# 2     chaotic        gritty      1     0.500000
# 3     chaotic          nice      1     0.500000
# 4   community    gentrified      1     1.000000
# 5     diverse       diverse      2     0.666667
# 6     diverse          food      1     0.333333
# 7         fun      antitask      1     0.045455
# 8         fun       chaotic      3     0.136364
# 9         fun       diverse      5     0.227273
# 10        fun          food      2     0.090909
# 11        fun           fun      6     0.272727
# 12        fun        gritty      1     0.045455
# 13        fun  institutions      1     0.045455
# 14        fun        latino      1     0.045455
# 15        fun          nice      1     0.045455
# 16        fun       special      1     0.045455
# 17        gay       actions      1     0.030303
# 18        gay       chaotic      1     0.030303
# 19        gay     community      1     0.030303
# 20        gay       diverse      5     0.151515
# 21        gay          food      2     0.060606
# 22        gay           fun      2     0.060606
# 23        gay           gay      1     0.030303
# 24        gay    gentrified      1     0.030303
# 25        gay        gritty      2     0.060606
# 26        gay        latino      9     0.272727
# 27        gay          nice      3     0.090909
# 28        gay         other      1     0.030303
# 29        gay       special      3     0.090909
# 30        gay         young      1     0.030303
# 31       nice      antitask      1     0.200000
# 32       nice          food      1     0.200000
# 33       nice           fun      1     0.200000
# 34       nice           gay      2     0.400000
# 35  normative          food      1     1.000000
# 36       open       diverse      1     0.500000
# 37       open           gay      1     0.500000
# 38      other       diverse      1     0.333333
# 39      other    gentrified      2     0.666667
# 40     sexual           bad      1     0.333333
# 41     sexual         other      1     0.333333
# 42     sexual        sexual      1     0.333333
# 43    special     community      1     0.333333
# 44    special        gritty      1     0.333333
# 45    special         other      1     0.333333
# Backward probability of response1 given response2 for castro_vis participants with response_site1=castro and response_site2=mission:
#     category1     category2  count  probability
# 17        gay       actions      1     1.000000
# 0      boring      antitask      1     0.333333
# 7         fun      antitask      1     0.333333
# 31       nice      antitask      1     0.333333
# 40     sexual           bad      1     1.000000
# 8         fun       chaotic      3     0.750000
# 18        gay       chaotic      1     0.250000
# 19        gay     community      1     0.500000
# 43    special     community      1     0.500000
# 1      change       diverse      1     0.066667
# 5     diverse       diverse      2     0.133333
# 9         fun       diverse      5     0.333333
# 20        gay       diverse      5     0.333333
# 36       open       diverse      1     0.066667
# 38      other       diverse      1     0.066667
# 6     diverse          food      1     0.142857
# 10        fun          food      2     0.285714
# 21        gay          food      2     0.285714
# 32       nice          food      1     0.142857
# 35  normative          food      1     0.142857
# 11        fun           fun      6     0.666667
# 22        gay           fun      2     0.222222
# 33       nice           fun      1     0.111111
# 23        gay           gay      1     0.250000
# 34       nice           gay      2     0.500000
# 37       open           gay      1     0.250000
# 4   community    gentrified      1     0.250000
# 24        gay    gentrified      1     0.250000
# 39      other    gentrified      2     0.500000
# 2     chaotic        gritty      1     0.200000
# 12        fun        gritty      1     0.200000
# 25        gay        gritty      2     0.400000
# 44    special        gritty      1     0.200000
# 13        fun  institutions      1     1.000000
# 14        fun        latino      1     0.100000
# 26        gay        latino      9     0.900000
# 3     chaotic          nice      1     0.200000
# 15        fun          nice      1     0.200000
# 27        gay          nice      3     0.600000
# 28        gay         other      1     0.333333
# 41     sexual         other      1     0.333333
# 45    special         other      1     0.333333
# 42     sexual        sexual      1     1.000000
# 16        fun       special      1     0.250000
# 29        gay       special      3     0.750000
# 30        gay         young      1     1.000000

# %% [markdown]
# ## Marina Residents

# %%
# Marina participants with response_site1=marina and response_site2=castro
prob.forward_prob(df, target_fieldsite="marina_res", target_r1_site="marina", target_r2_site="castro", count_filter=0)
prob.backward_prob(df, target_fieldsite="marina_res", target_r1_site="marina", target_r2_site="castro", count_filter=0)

# Marina participants with response_site1=marina and response_site2=mission
prob.forward_prob(df, target_fieldsite="marina_res", target_r1_site="castro", target_r2_site="marina", count_filter=0)
prob.backward_prob(df, target_fieldsite="marina_res", target_r1_site="castro", target_r2_site="marina", count_filter=0)
# Out:
# Forward probability of response2 given response1 for marina_res participants with response_site1=marina and response_site2=castro:
#        category1  category2  count  probability
# 0        actions   antitask      1     1.000000
# 1            bad     boring      1     0.500000
# 2            bad        gay      1     0.500000
# 3         boring        fun      1     0.500000
# 4         boring      other      1     0.500000
# 5        chaotic    diverse      1     0.500000
# 6        chaotic        fun      1     0.500000
# 7      community   antitask      4     1.000000
# 8        diverse       nice      1     1.000000
# 9            fun   antitask      3     0.250000
# 10           fun    diverse      2     0.166667
# 11           fun        fun      6     0.500000
# 12           fun      other      1     0.083333
# 13    gentrified   antitask      2     0.133333
# 14    gentrified    diverse      1     0.066667
# 15    gentrified        fun      4     0.266667
# 16    gentrified        gay      8     0.533333
# 17     geography   antitask      2     0.285714
# 18     geography  community      1     0.142857
# 19     geography        gay      1     0.142857
# 20     geography  geography      3     0.428571
# 21  institutions   antitask      1     1.000000
# 22          nice   antitask      5     0.357143
# 23          nice    chaotic      1     0.071429
# 24          nice        fun      3     0.214286
# 25          nice        gay      3     0.214286
# 26          nice       nice      1     0.071429
# 27          nice      other      1     0.071429
# 28     normative   antitask      1     0.166667
# 29     normative     boring      1     0.166667
# 30     normative        fun      2     0.333333
# 31     normative       nice      1     0.166667
# 32     normative       open      1     0.166667
# 33         other   antitask      3     0.500000
# 34         other        fun      1     0.166667
# 35         other        gay      2     0.333333
# 36       special        fun      1     0.500000
# 37       special      other      1     0.500000
# 38       weather   antitask      1     1.000000
# 39         young     change      1     0.333333
# 40         young        gay      2     0.666667
# Backward probability of response1 given response2 for marina_res participants with response_site1=marina and response_site2=castro:
#        category1  category2  count  probability
# 0        actions   antitask      1     0.043478
# 7      community   antitask      4     0.173913
# 9            fun   antitask      3     0.130435
# 13    gentrified   antitask      2     0.086957
# 17     geography   antitask      2     0.086957
# 21  institutions   antitask      1     0.043478
# 22          nice   antitask      5     0.217391
# 28     normative   antitask      1     0.043478
# 33         other   antitask      3     0.130435
# 38       weather   antitask      1     0.043478
# 1            bad     boring      1     0.500000
# 29     normative     boring      1     0.500000
# 39         young     change      1     1.000000
# 23          nice    chaotic      1     1.000000
# 18     geography  community      1     1.000000
# 5        chaotic    diverse      1     0.250000
# 10           fun    diverse      2     0.500000
# 14    gentrified    diverse      1     0.250000
# 3         boring        fun      1     0.052632
# 6        chaotic        fun      1     0.052632
# 11           fun        fun      6     0.315789
# 15    gentrified        fun      4     0.210526
# 24          nice        fun      3     0.157895
# 30     normative        fun      2     0.105263
# 34         other        fun      1     0.052632
# 36       special        fun      1     0.052632
# 2            bad        gay      1     0.058824
# 16    gentrified        gay      8     0.470588
# 19     geography        gay      1     0.058824
# 25          nice        gay      3     0.176471
# 35         other        gay      2     0.117647
# 40         young        gay      2     0.117647
# 20     geography  geography      3     1.000000
# 8        diverse       nice      1     0.333333
# 26          nice       nice      1     0.333333
# 31     normative       nice      1     0.333333
# 32     normative       open      1     1.000000
# 4         boring      other      1     0.250000
# 12           fun      other      1     0.250000
# 27          nice      other      1     0.250000
# 37       special      other      1     0.250000
# Forward probability of response2 given response1 for marina_res participants with response_site1=castro and response_site2=marina:
#        category1     category2  count  probability
# 0       antitask       actions      1     0.125000
# 1       antitask           fun      1     0.125000
# 2       antitask    gentrified      2     0.250000
# 3       antitask     geography      1     0.125000
# 4       antitask          nice      2     0.250000
# 5       antitask         other      1     0.125000
# 6         boring           fun      1     1.000000
# 7        diverse          nice      1     0.500000
# 8        diverse         young      1     0.500000
# 9            fun       actions      1     0.045455
# 10           fun        boring      1     0.045455
# 11           fun       chaotic      2     0.090909
# 12           fun       diverse      1     0.045455
# 13           fun           fun      2     0.090909
# 14           fun    gentrified      1     0.045455
# 15           fun     geography      2     0.090909
# 16           fun  institutions      1     0.045455
# 17           fun          nice      4     0.181818
# 18           fun     normative      3     0.136364
# 19           fun         other      1     0.045455
# 20           fun         young      3     0.136364
# 21           gay      antitask      1     0.037037
# 22           gay        boring      1     0.037037
# 23           gay    gentrified     10     0.370370
# 24           gay     geography      1     0.037037
# 25           gay          nice      1     0.037037
# 26           gay     normative      8     0.296296
# 27           gay         other      4     0.148148
# 28           gay         young      1     0.037037
# 29     geography    gentrified      1     0.500000
# 30     geography     geography      1     0.500000
# 31  institutions           fun      1     0.200000
# 32  institutions     geography      1     0.200000
# 33  institutions  institutions      1     0.200000
# 34  institutions         other      2     0.400000
# 35          nice        change      1     0.500000
# 36          nice          nice      1     0.500000
# 37         other       actions      1     0.333333
# 38         other         other      1     0.333333
# 39         other         young      1     0.333333
# 40       special          nice      1     1.000000
# Backward probability of response1 given response2 for marina_res participants with response_site1=castro and response_site2=marina:
#        category1     category2  count  probability
# 0       antitask       actions      1     0.333333
# 9            fun       actions      1     0.333333
# 37         other       actions      1     0.333333
# 21           gay      antitask      1     1.000000
# 10           fun        boring      1     0.500000
# 22           gay        boring      1     0.500000
# 35          nice        change      1     1.000000
# 11           fun       chaotic      2     1.000000
# 12           fun       diverse      1     1.000000
# 1       antitask           fun      1     0.200000
# 6         boring           fun      1     0.200000
# 13           fun           fun      2     0.400000
# 31  institutions           fun      1     0.200000
# 2       antitask    gentrified      2     0.142857
# 14           fun    gentrified      1     0.071429
# 23           gay    gentrified     10     0.714286
# 29     geography    gentrified      1     0.071429
# 3       antitask     geography      1     0.166667
# 15           fun     geography      2     0.333333
# 24           gay     geography      1     0.166667
# 30     geography     geography      1     0.166667
# 32  institutions     geography      1     0.166667
# 16           fun  institutions      1     0.500000
# 33  institutions  institutions      1     0.500000
# 4       antitask          nice      2     0.200000
# 7        diverse          nice      1     0.100000
# 17           fun          nice      4     0.400000
# 25           gay          nice      1     0.100000
# 36          nice          nice      1     0.100000
# 40       special          nice      1     0.100000
# 18           fun     normative      3     0.272727
# 26           gay     normative      8     0.727273
# 5       antitask         other      1     0.111111
# 19           fun         other      1     0.111111
# 27           gay         other      4     0.444444
# 34  institutions         other      2     0.222222
# 38         other         other      1     0.111111
# 8        diverse         young      1     0.166667
# 20           fun         young      3     0.500000
# 28           gay         young      1     0.166667
# 39         other         young      1     0.166667

# %% [markdown]
# ## Mission Residents

# %%
# Mission participants with response_site1=mission and response_site2=castro
prob.forward_prob(df, target_fieldsite="mission_res", target_r1_site="mission", target_r2_site="castro", count_filter=0)
prob.backward_prob(df, target_fieldsite="mission_res", target_r1_site="mission", target_r2_site="castro", count_filter=0)

# Mission participants with response_site1=castro and response_site2=mission
prob.forward_prob(df, target_fieldsite="mission_res", target_r1_site="castro", target_r2_site="mission", count_filter=0)
prob.backward_prob(df, target_fieldsite="mission_res", target_r1_site="castro", target_r2_site="mission", count_filter=0)
# Out:
# Forward probability of response2 given response1 for mission_res participants with response_site1=mission and response_site2=castro:
#      category1   category2  count  probability
# 0          bad         gay      1     1.000000
# 1      chaotic         fun      1     1.000000
# 2    community   community      2     0.333333
# 3    community         fun      1     0.166667
# 4    community   geography      1     0.166667
# 5    community        nice      1     0.166667
# 6    community     special      1     0.166667
# 7      diverse     diverse      2     0.166667
# 8      diverse         fun      6     0.500000
# 9      diverse         gay      3     0.250000
# 10     diverse  gentrified      1     0.083333
# 11         fun      boring      1     0.055556
# 12         fun   community      1     0.055556
# 13         fun     diverse      2     0.111111
# 14         fun         fun      9     0.500000
# 15         fun         gay      2     0.111111
# 16         fun        nice      2     0.111111
# 17         fun     special      1     0.055556
# 18  gentrified         gay      2     0.666667
# 19  gentrified  gentrified      1     0.333333
# 20   geography         gay      1     1.000000
# 21      gritty         gay      2     0.500000
# 22      gritty        nice      2     0.500000
# 23      latino   community      2     0.250000
# 24      latino         gay      2     0.250000
# 25      latino       other      3     0.375000
# 26      latino      sexual      1     0.125000
# 27        nice     chaotic      1     0.083333
# 28        nice         fun      1     0.083333
# 29        nice         gay      2     0.166667
# 30        nice   geography      1     0.083333
# 31        nice        nice      7     0.583333
# 32       other     diverse      2     0.500000
# 33       other         fun      1     0.250000
# 34       other         gay      1     0.250000
# 35     special    antitask      2     0.153846
# 36     special     diverse      2     0.153846
# 37     special         fun      1     0.076923
# 38     special         gay      2     0.153846
# 39     special        nice      1     0.076923
# 40     special        open      2     0.153846
# 41     special       other      2     0.153846
# 42     special     special      1     0.076923
# 43     weather     diverse      1     1.000000
# Backward probability of response1 given response2 for mission_res participants with response_site1=mission and response_site2=castro:
#      category1   category2  count  probability
# 35     special    antitask      2     1.000000
# 11         fun      boring      1     1.000000
# 27        nice     chaotic      1     1.000000
# 2    community   community      2     0.400000
# 12         fun   community      1     0.200000
# 23      latino   community      2     0.400000
# 7      diverse     diverse      2     0.222222
# 13         fun     diverse      2     0.222222
# 32       other     diverse      2     0.222222
# 36     special     diverse      2     0.222222
# 43     weather     diverse      1     0.111111
# 1      chaotic         fun      1     0.050000
# 3    community         fun      1     0.050000
# 8      diverse         fun      6     0.300000
# 14         fun         fun      9     0.450000
# 28        nice         fun      1     0.050000
# 33       other         fun      1     0.050000
# 37     special         fun      1     0.050000
# 0          bad         gay      1     0.055556
# 9      diverse         gay      3     0.166667
# 15         fun         gay      2     0.111111
# 18  gentrified         gay      2     0.111111
# 20   geography         gay      1     0.055556
# 21      gritty         gay      2     0.111111
# 24      latino         gay      2     0.111111
# 29        nice         gay      2     0.111111
# 34       other         gay      1     0.055556
# 38     special         gay      2     0.111111
# 10     diverse  gentrified      1     0.500000
# 19  gentrified  gentrified      1     0.500000
# 4    community   geography      1     0.500000
# 30        nice   geography      1     0.500000
# 5    community        nice      1     0.076923
# 16         fun        nice      2     0.153846
# 22      gritty        nice      2     0.153846
# 31        nice        nice      7     0.538462
# 39     special        nice      1     0.076923
# 40     special        open      2     1.000000
# 25      latino       other      3     0.600000
# 41     special       other      2     0.400000
# 26      latino      sexual      1     1.000000
# 6    community     special      1     0.333333
# 17         fun     special      1     0.333333
# 42     special     special      1     0.333333
# Forward probability of response2 given response1 for mission_res participants with response_site1=castro and response_site2=mission:
#        category1     category2  count  probability
# 0       antitask       diverse      1     0.250000
# 1       antitask    gentrified      1     0.250000
# 2       antitask        latino      1     0.250000
# 3       antitask          nice      1     0.250000
# 4            bad         other      1     1.000000
# 5        chaotic          food      2     1.000000
# 6        diverse      antitask      1     0.142857
# 7        diverse       diverse      2     0.285714
# 8        diverse          food      1     0.142857
# 9        diverse           fun      1     0.142857
# 10       diverse        latino      2     0.285714
# 11           fun      antitask      1     0.052632
# 12           fun     community      1     0.052632
# 13           fun       diverse      2     0.105263
# 14           fun          food      2     0.105263
# 15           fun           fun     11     0.578947
# 16           fun        gritty      1     0.052632
# 17           fun  institutions      1     0.052632
# 18           gay      antitask      5     0.166667
# 19           gay     community      1     0.033333
# 20           gay       diverse      8     0.266667
# 21           gay          food      1     0.033333
# 22           gay           fun      7     0.233333
# 23           gay        gritty      1     0.033333
# 24           gay        latino      5     0.166667
# 25           gay         other      1     0.033333
# 26           gay       weather      1     0.033333
# 27    gentrified    gentrified      1     1.000000
# 28     geography     geography      1     0.500000
# 29     geography        latino      1     0.500000
# 30        gritty        gritty      1     1.000000
# 31  institutions        latino      1     1.000000
# 32          nice       diverse      1     0.250000
# 33          nice    gentrified      1     0.250000
# 34          nice        gritty      1     0.250000
# 35          nice          nice      1     0.250000
# 36     normative        gritty      1     0.500000
# 37     normative     normative      1     0.500000
# 38         other           bad      1     0.250000
# 39         other       diverse      2     0.500000
# 40         other        latino      1     0.250000
# 41       special        latino      1     0.250000
# 42       special          nice      1     0.250000
# 43       special       special      2     0.500000
# Backward probability of response1 given response2 for mission_res participants with response_site1=castro and response_site2=mission:
#        category1     category2  count  probability
# 6        diverse      antitask      1     0.142857
# 11           fun      antitask      1     0.142857
# 18           gay      antitask      5     0.714286
# 38         other           bad      1     1.000000
# 12           fun     community      1     0.500000
# 19           gay     community      1     0.500000
# 0       antitask       diverse      1     0.062500
# 7        diverse       diverse      2     0.125000
# 13           fun       diverse      2     0.125000
# 20           gay       diverse      8     0.500000
# 32          nice       diverse      1     0.062500
# 39         other       diverse      2     0.125000
# 5        chaotic          food      2     0.333333
# 8        diverse          food      1     0.166667
# 14           fun          food      2     0.333333
# 21           gay          food      1     0.166667
# 9        diverse           fun      1     0.052632
# 15           fun           fun     11     0.578947
# 22           gay           fun      7     0.368421
# 1       antitask    gentrified      1     0.333333
# 27    gentrified    gentrified      1     0.333333
# 33          nice    gentrified      1     0.333333
# 28     geography     geography      1     1.000000
# 16           fun        gritty      1     0.200000
# 23           gay        gritty      1     0.200000
# 30        gritty        gritty      1     0.200000
# 34          nice        gritty      1     0.200000
# 36     normative        gritty      1     0.200000
# 17           fun  institutions      1     1.000000
# 2       antitask        latino      1     0.083333
# 10       diverse        latino      2     0.166667
# 24           gay        latino      5     0.416667
# 29     geography        latino      1     0.083333
# 31  institutions        latino      1     0.083333
# 40         other        latino      1     0.083333
# 41       special        latino      1     0.083333
# 3       antitask          nice      1     0.333333
# 35          nice          nice      1     0.333333
# 42       special          nice      1     0.333333
# 37     normative     normative      1     1.000000
# 4            bad         other      1     0.500000
# 25           gay         other      1     0.500000
# 43       special       special      2     1.000000
# 26           gay       weather      1     1.000000

# %% [markdown]
# # Single word clean analysis
#
# ## Straight

# %%
prob.single_word_prob(df_all, target_fieldsite="marina_res", 
                      target_word="straight", word_col= "clean_response2", w1_col = "category1",
                      target_r1_site="castro", target_r2_site="marina", 
                      count_filter=0)

prob.single_word_prob(df_all, target_fieldsite="marina_res", 
                      target_word="straight", word_col= "clean_response1", w1_col = "category2",
                      target_r1_site="marina", target_r2_site="castro", 
                      count_filter=0)

prob.single_word_prob(df_all, target_fieldsite="castro_res", 
                      target_word="straight", word_col= "clean_response2", w1_col = "category1",
                      target_r1_site="castro", target_r2_site="marina", 
                      count_filter=0)

prob.single_word_prob(df_all, target_fieldsite="castro_vis", 
                      target_word="straight", word_col= "clean_response2", w1_col = "category1",
                      target_r1_site="castro", target_r2_site="marina", 
                      count_filter=0)
# Out:
# Probability of straight in position clean_response2 for marina_res participants with response_site1=castro and response_site2=marina:
#   category1 clean_response2  count  probability
# 0       fun        straight      1          1.0
# Probability of straight in position clean_response1 for marina_res participants with response_site1=marina and response_site2=castro:
# Empty DataFrame
# Columns: [category2, clean_response1, count, probability]
# Index: []
# Probability of straight in position clean_response2 for castro_res participants with response_site1=castro and response_site2=marina:
#   category1 clean_response2  count  probability
# 0       gay        straight      2          1.0
# Probability of straight in position clean_response2 for castro_vis participants with response_site1=castro and response_site2=marina:
#   category1 clean_response2  count  probability
# 0       gay        straight      6     0.857143
# 1      nice        straight      1     0.142857

# %% [markdown]
# ## Latino

# %%
prob.single_word_prob(df_all, target_fieldsite="mission_res", 
                      target_word="latino", word_col= "clean_response2", w1_col = "category1",
                      target_r1_site="castro", target_r2_site="mission", 
                      count_filter=0)

prob.single_word_prob(df_all, target_fieldsite="mission_res", 
                      target_word="latino", word_col= "clean_response1", w1_col = "category2",
                      target_r1_site="mission", target_r2_site="castro", 
                      count_filter=0)

prob.single_word_prob(df_all, target_fieldsite="castro_res", 
                      target_word="latino", word_col= "clean_response2", w1_col = "category1",
                      target_r1_site="castro", target_r2_site="mission", 
                      count_filter=0)

prob.single_word_prob(df_all, target_fieldsite="castro_vis", 
                      target_word="latino", word_col= "clean_response2", w1_col = "category1",
                      target_r1_site="castro", target_r2_site="mission", 
                      count_filter=0)
# Out:
# Probability of latino in position clean_response2 for mission_res participants with response_site1=castro and response_site2=mission:
#       category1 clean_response2  count  probability
# 0      antitask          latino      1     0.111111
# 1           gay          latino      4     0.444444
# 2     geography          latino      1     0.111111
# 3  institutions          latino      1     0.111111
# 4         other          latino      1     0.111111
# 5       special          latino      1     0.111111
# Probability of latino in position clean_response1 for mission_res participants with response_site1=mission and response_site2=castro:
#    category2 clean_response1  count  probability
# 0  community          latino      2          0.4
# 1        gay          latino      1          0.2
# 2      other          latino      2          0.4
# Probability of latino in position clean_response2 for castro_res participants with response_site1=castro and response_site2=mission:
#   category1 clean_response2  count  probability
# 0       gay          latino      5          1.0
# Probability of latino in position clean_response2 for castro_vis participants with response_site1=castro and response_site2=mission:
#   category1 clean_response2  count  probability
# 0       fun          latino      1         0.25
# 1       gay          latino      3         0.75
